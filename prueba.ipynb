# %%
import requests
# URL del archivo
url = "https://raw.githubusercontent.com/abelalv/prueba2/main/libreria.py"
# Descargar el archivo
response = requests.get(url)
with open('libreria.py', 'w') as file:
    file.write(response.text)

# Importar la librería descargada
import libreria

# %%
import libreria as lc
import numpy as np

x=np.array([1,2,3,4,5])
z=lc.media_a(x)
print(z)
